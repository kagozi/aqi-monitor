# %%
import numpy as np
import gymnasium as gym # Updated import for gym
from gymnasium import spaces
from scipy.stats import norm
from stable_baselines3.common.callbacks import CheckpointCallback, EvalCallback, BaseCallback
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.logger import configure
import time

# %%
class AirQualityDiscreteEnv(gym.Env):
    def __init__(self):
        super(AirQualityDiscreteEnv, self).__init__()
        
        # New discrete action space: 0 = no change, 1 = increase by 0.1, 2 = decrease by 0.1
        self.action_space = spaces.Discrete(3)
        
        # State space remains the same
        self.observation_space = spaces.Box(
            low=np.array([0, 0, 0, 0]),
            high=np.array([500, 5, 24, 100]),
            dtype=np.float32
        )
        
        # Fan parameters (5V DC fan)
        self.fan_voltage = 2.5  # Initial voltage (V)
        self.max_voltage = 5.0
        self.min_voltage = 0.0
        self.voltage_step = 0.1  # Voltage change per action
        self.voltage_to_speed = 1.0  # Conversion factor (m/s per volt)
        
        # Rest of your existing initialization...
        self.Q = 80  # Emission rate (μg/s)
        self.H = 1.5  # Effective stack height (m)
        self.y = 0    # Cross-wind distance (m)
        self.z = 1.2  # Receptor height (m)
        self.x = 2.0  # Downwind distance (m)
        
        self.stability_class = 'D'
        self.stability_params = {
            'A': {'σy': 0.22, 'σz': 0.20},
            'D': {'σy': 0.08, 'σz': 0.06},
            'F': {'σy': 0.04, 'σz': 0.03}
        }
        
        self.aqi_breakpoints = [
            (0, 12.0, 0, 50),
            (12.1, 35.4, 51, 100),
            (35.5, 55.4, 101, 150),
            (55.5, 150.4, 151, 200),
            (150.5, 250.4, 201, 300),
            (250.5, 500.4, 301, 500)
        ]
        
        self.time = 8.0  # Start at 8 AM
        self.time_step = 0.1  # 6-minute intervals
        
        self.fan_resistance = 10  # Ohms
        self.energy_coeff = 0.001  # Scaling factor for reward
        
    def _voltage_to_wind_speed(self, voltage):
        """Convert fan voltage to wind speed (m/s)"""
        return voltage * self.voltage_to_speed
    
    def _gaussian_plume_model(self, wind_speed):
        """Calculate pollutant concentration using Gaussian plume model"""
        params = self.stability_params[self.stability_class]
        σy = params['σy'] * self.x  # Downwind distance multiplier
        σz = params['σz'] * self.x

        # Prevent division by zero
        epsilon = 1e-6
        wind_speed = max(wind_speed, epsilon)
        σy = max(σy, epsilon)
        σz = max(σz, epsilon)
        
        # Simplified 3D Gaussian plume (centerline, so y=0)
        term1 = self.Q / (2 * np.pi * σy * σz * wind_speed)
        term2 = np.exp(-(self.z - self.H)**2 / (2 * σz**2))
        term3 = np.exp(-(self.z + self.H)**2 / (2 * σz**2))
        
        concentration = term1 * (term2 + term3)
        return max(concentration, 0.1)  # Prevent division by zero
    
    def _calculate_aqi(self, concentration):
        """Convert PM2.5 concentration to AQI"""
        for (c_low, c_high, i_low, i_high) in self.aqi_breakpoints:
            if c_low <= concentration <= c_high:
                return ((i_high - i_low)/(c_high - c_low)) * (concentration - c_low) + i_low
        return 500  # Beyond hazardous
    
    def _calculate_energy(self):
        """Calculate fan energy consumption (Joules)"""
        current = self.fan_voltage / self.fan_resistance
        power = self.fan_voltage * current
        return power * (self.time_step * 3600)  # Convert hours to seconds
    
    def step(self, action):
        """Execute one time step within the environment"""
        # Get the current voltage from the observation
    
        # Handle discrete actions
        if action == 1:  # Increase voltage
            self.fan_voltage = min(self.fan_voltage + self.voltage_step, self.max_voltage)
        elif action == 2:  # Decrease voltage
            self.fan_voltage = max(self.fan_voltage - self.voltage_step, self.min_voltage)
        # Else action == 0: no change
        wind_speed = self._voltage_to_wind_speed(self.fan_voltage)
        source_variation = 1 + 0.5 * np.sin(2 * np.pi * self.time/24)
        effective_Q = self.Q * source_variation
        
        concentration = self._gaussian_plume_model(wind_speed)
        aqi = self._calculate_aqi(concentration)
        energy = self._calculate_energy()
        
        self.time = (self.time + self.time_step) % 24
        
        # Reward function
        aqi_error = abs(aqi - 50)  # Target AQI 50
        reward = (1 / (1 + 0.1*aqi_error)) - self.energy_coeff * energy
        
        state = np.array([aqi, self.fan_voltage, self.time, effective_Q], dtype=np.float32)
        done = self.time < 0.1  # Full day completed
        terminated = self.time < 0.1  # End of the day
        truncated = False  # You can also add a timeout condition here if needed
        return state, reward, terminated, truncated, {
            'concentration': concentration,
            'energy': energy,
            'wind_speed': wind_speed
        }

    
    def reset(self, seed=None, options=None):
        super().reset(seed=seed)  # Required for Gymnasium
        self.fan_voltage = 2.5
        self.time = 8.0
        state = np.array([
            self._calculate_aqi(self._gaussian_plume_model(2.5)),
            self.fan_voltage,
            self.time,
            self.Q
        ], dtype=np.float32)
        return state, {}

    
    def render(self, mode='human'):
        wind_speed = self._voltage_to_wind_speed(self.fan_voltage)
        concentration = self._gaussian_plume_model(wind_speed)
        print(f"Voltage: {self.fan_voltage:.2f}V | Wind: {wind_speed:.2f}m/s | "
              f"PM2.5: {concentration:.2f}μg/m³ | AQI: {self._calculate_aqi(concentration):.0f}")

# %%
# Example usage with random actions
if __name__ == "__main__":
    env = AirQualityDiscreteEnv()
    obs = env.reset()
    
    # Test with random control
    for i in range(100):
        # Generate random action between [0,1, 2]
        # time.sleep(1)
        action = env.action_space.sample()
        
        obs, reward, terminated, truncated, info = env.step(action)
        env.render()
        
        print(f"Step {i+1}: Action={action} | Reward={reward:.3f} | Energy={info['energy']:.2f}J")
        
        if terminated or truncated:
            print("Resetting environment after full day cycle")
            obs = env.reset()
# Out:
# Voltage: 2.50V | Wind: 2.50m/s | PM2.5: 11.65μg/m³ | AQI: 49
# Step 1: Action=0 | Reward=0.649 | Energy=225.00J
# Voltage: 2.50V | Wind: 2.50m/s | PM2.5: 11.65μg/m³ | AQI: 49
# Step 2: Action=0 | Reward=0.649 | Energy=225.00J
# Voltage: 2.40V | Wind: 2.40m/s | PM2.5: 12.14μg/m³ | AQI: 51
# Step 3: Action=2 | Reward=0.695 | Energy=207.36J
# Voltage: 2.40V | Wind: 2.40m/s | PM2.5: 12.14μg/m³ | AQI: 51
# Step 4: Action=0 | Reward=0.695 | Energy=207.36J
# Voltage: 2.40V | Wind: 2.40m/s | PM2.5: 12.14μg/m³ | AQI: 51
# Step 5: Action=0 | Reward=0.695 | Energy=207.36J
# Voltage: 2.40V | Wind: 2.40m/s | PM2.5: 12.14μg/m³ | AQI: 51
# Step 6: Action=0 | Reward=0.695 | Energy=207.36J
# Voltage: 2.50V | Wind: 2.50m/s | PM2.5: 11.65μg/m³ | AQI: 49
# Step 7: Action=1 | Reward=0.649 | Energy=225.00J
# Voltage: 2.60V | Wind: 2.60m/s | PM2.5: 11.21μg/m³ | AQI: 47
# Step 8: Action=1 | Reward=0.508 | Energy=243.36J
# Voltage: 2.50V | Wind: 2.50m/s | PM2.5: 11.65μg/m³ | AQI: 49
# Step 9: Action=2 | Reward=0.649 | Energy=225.00J
# Voltage: 2.50V | Wind: 2.50m/s | PM2.5: 11.65μg/m³ | AQI: 49
# Step 10: Action=0 | Reward=0.649 | Energy=225.00J
# Voltage: 2.40V | Wind: 2.40m/s | PM2.5: 12.14μg/m³ | AQI: 51
# Step 11: Action=2 | Reward=0.695 | Energy=207.36J
# Voltage: 2.30V | Wind: 2.30m/s | PM2.5: 12.67μg/m³ | AQI: 52
# Step 12: Action=2 | Reward=0.630 | Energy=190.44J
# Voltage: 2.30V | Wind: 2.30m/s | PM2.5: 12.67μg/m³ | AQI: 52
# Step 13: Action=0 | Reward=0.630 | Energy=190.44J
# Voltage: 2.40V | Wind: 2.40m/s | PM2.5: 12.14μg/m³ | AQI: 51
# Step 14: Action=1 | Reward=0.695 | Energy=207.36J
# Voltage: 2.30V | Wind: 2.30m/s | PM2.5: 12.67μg/m³ | AQI: 52
# Step 15: Action=2 | Reward=0.630 | Energy=190.44J
# Voltage: 2.20V | Wind: 2.20m/s | PM2.5: 13.24μg/m³ | AQI: 53
# Step 16: Action=2 | Reward=0.572 | Energy=174.24J
# Voltage: 2.30V | Wind: 2.30m/s | PM2.5: 12.67μg/m³ | AQI: 52
# Step 17: Action=1 | Reward=0.630 | Energy=190.44J
# Voltage: 2.40V | Wind: 2.40m/s | PM2.5: 12.14μg/m³ | AQI: 51
# Step 18: Action=1 | Reward=0.695 | Energy=207.36J
# Voltage: 2.50V | Wind: 2.50m/s | PM2.5: 11.65μg/m³ | AQI: 49
# Step 19: Action=1 | Reward=0.649 | Energy=225.00J
# Voltage: 2.60V | Wind: 2.60m/s | PM2.5: 11.21μg/m³ | AQI: 47
# Step 20: Action=1 | Reward=0.508 | Energy=243.36J
# Voltage: 2.60V | Wind: 2.60m/s | PM2.5: 11.21μg/m³ | AQI: 47
# Step 21: Action=0 | Reward=0.508 | Energy=243.36J
# Voltage: 2.50V | Wind: 2.50m/s | PM2.5: 11.65μg/m³ | AQI: 49
# Step 22: Action=2 | Reward=0.649 | Energy=225.00J
# Voltage: 2.40V | Wind: 2.40m/s | PM2.5: 12.14μg/m³ | AQI: 51
# Step 23: Action=2 | Reward=0.695 | Energy=207.36J
# Voltage: 2.50V | Wind: 2.50m/s | PM2.5: 11.65μg/m³ | AQI: 49
# Step 24: Action=1 | Reward=0.649 | Energy=225.00J
# Voltage: 2.40V | Wind: 2.40m/s | PM2.5: 12.14μg/m³ | AQI: 51
# Step 25: Action=2 | Reward=0.695 | Energy=207.36J
# Voltage: 2.50V | Wind: 2.50m/s | PM2.5: 11.65μg/m³ | AQI: 49
# Step 26: Action=1 | Reward=0.649 | Energy=225.00J
# Voltage: 2.50V | Wind: 2.50m/s | PM2.5: 11.65μg/m³ | AQI: 49
# Step 27: Action=0 | Reward=0.649 | Energy=225.00J
# Voltage: 2.40V | Wind: 2.40m/s | PM2.5: 12.14μg/m³ | AQI: 51
# Step 28: Action=2 | Reward=0.695 | Energy=207.36J
# Voltage: 2.40V | Wind: 2.40m/s | PM2.5: 12.14μg/m³ | AQI: 51
# Step 29: Action=0 | Reward=0.695 | Energy=207.36J
# Voltage: 2.30V | Wind: 2.30m/s | PM2.5: 12.67μg/m³ | AQI: 52
# Step 30: Action=2 | Reward=0.630 | Energy=190.44J
# Voltage: 2.20V | Wind: 2.20m/s | PM2.5: 13.24μg/m³ | AQI: 53
# Step 31: Action=2 | Reward=0.572 | Energy=174.24J
# Voltage: 2.30V | Wind: 2.30m/s | PM2.5: 12.67μg/m³ | AQI: 52
# Step 32: Action=1 | Reward=0.630 | Energy=190.44J
# Voltage: 2.40V | Wind: 2.40m/s | PM2.5: 12.14μg/m³ | AQI: 51
# Step 33: Action=1 | Reward=0.695 | Energy=207.36J
# Voltage: 2.40V | Wind: 2.40m/s | PM2.5: 12.14μg/m³ | AQI: 51
# Step 34: Action=0 | Reward=0.695 | Energy=207.36J
# Voltage: 2.30V | Wind: 2.30m/s | PM2.5: 12.67μg/m³ | AQI: 52
# Step 35: Action=2 | Reward=0.630 | Energy=190.44J
# Voltage: 2.20V | Wind: 2.20m/s | PM2.5: 13.24μg/m³ | AQI: 53
# Step 36: Action=2 | Reward=0.572 | Energy=174.24J
# Voltage: 2.30V | Wind: 2.30m/s | PM2.5: 12.67μg/m³ | AQI: 52
# Step 37: Action=1 | Reward=0.630 | Energy=190.44J
# Voltage: 2.40V | Wind: 2.40m/s | PM2.5: 12.14μg/m³ | AQI: 51
# Step 38: Action=1 | Reward=0.695 | Energy=207.36J
# Voltage: 2.30V | Wind: 2.30m/s | PM2.5: 12.67μg/m³ | AQI: 52
# Step 39: Action=2 | Reward=0.630 | Energy=190.44J
# Voltage: 2.40V | Wind: 2.40m/s | PM2.5: 12.14μg/m³ | AQI: 51
# Step 40: Action=1 | Reward=0.695 | Energy=207.36J
# Voltage: 2.40V | Wind: 2.40m/s | PM2.5: 12.14μg/m³ | AQI: 51
# Step 41: Action=0 | Reward=0.695 | Energy=207.36J
# Voltage: 2.40V | Wind: 2.40m/s | PM2.5: 12.14μg/m³ | AQI: 51
# Step 42: Action=0 | Reward=0.695 | Energy=207.36J
# Voltage: 2.30V | Wind: 2.30m/s | PM2.5: 12.67μg/m³ | AQI: 52
# Step 43: Action=2 | Reward=0.630 | Energy=190.44J
# Voltage: 2.40V | Wind: 2.40m/s | PM2.5: 12.14μg/m³ | AQI: 51
# Step 44: Action=1 | Reward=0.695 | Energy=207.36J
# Voltage: 2.50V | Wind: 2.50m/s | PM2.5: 11.65μg/m³ | AQI: 49
# Step 45: Action=1 | Reward=0.649 | Energy=225.00J
# Voltage: 2.60V | Wind: 2.60m/s | PM2.5: 11.21μg/m³ | AQI: 47
# Step 46: Action=1 | Reward=0.508 | Energy=243.36J
# Voltage: 2.60V | Wind: 2.60m/s | PM2.5: 11.21μg/m³ | AQI: 47
# Step 47: Action=0 | Reward=0.508 | Energy=243.36J
# Voltage: 2.50V | Wind: 2.50m/s | PM2.5: 11.65μg/m³ | AQI: 49
# Step 48: Action=2 | Reward=0.649 | Energy=225.00J
# Voltage: 2.50V | Wind: 2.50m/s | PM2.5: 11.65μg/m³ | AQI: 49
# Step 49: Action=0 | Reward=0.649 | Energy=225.00J
# Voltage: 2.50V | Wind: 2.50m/s | PM2.5: 11.65μg/m³ | AQI: 49
# Step 50: Action=0 | Reward=0.649 | Energy=225.00J
# Voltage: 2.50V | Wind: 2.50m/s | PM2.5: 11.65μg/m³ | AQI: 49
# Step 51: Action=0 | Reward=0.649 | Energy=225.00J
# Voltage: 2.50V | Wind: 2.50m/s | PM2.5: 11.65μg/m³ | AQI: 49
# Step 52: Action=0 | Reward=0.649 | Energy=225.00J
# Voltage: 2.60V | Wind: 2.60m/s | PM2.5: 11.21μg/m³ | AQI: 47
# Step 53: Action=1 | Reward=0.508 | Energy=243.36J
# Voltage: 2.50V | Wind: 2.50m/s | PM2.5: 11.65μg/m³ | AQI: 49
# Step 54: Action=2 | Reward=0.649 | Energy=225.00J
# Voltage: 2.40V | Wind: 2.40m/s | PM2.5: 12.14μg/m³ | AQI: 51
# Step 55: Action=2 | Reward=0.695 | Energy=207.36J
# Voltage: 2.50V | Wind: 2.50m/s | PM2.5: 11.65μg/m³ | AQI: 49
# Step 56: Action=1 | Reward=0.649 | Energy=225.00J
# Voltage: 2.40V | Wind: 2.40m/s | PM2.5: 12.14μg/m³ | AQI: 51
# Step 57: Action=2 | Reward=0.695 | Energy=207.36J
# Voltage: 2.50V | Wind: 2.50m/s | PM2.5: 11.65μg/m³ | AQI: 49
# Step 58: Action=1 | Reward=0.649 | Energy=225.00J
# Voltage: 2.60V | Wind: 2.60m/s | PM2.5: 11.21μg/m³ | AQI: 47
# Step 59: Action=1 | Reward=0.508 | Energy=243.36J
# Voltage: 2.60V | Wind: 2.60m/s | PM2.5: 11.21μg/m³ | AQI: 47
# Step 60: Action=0 | Reward=0.508 | Energy=243.36J
# Voltage: 2.70V | Wind: 2.70m/s | PM2.5: 10.79μg/m³ | AQI: 45
# Step 61: Action=1 | Reward=0.403 | Energy=262.44J
# Voltage: 2.60V | Wind: 2.60m/s | PM2.5: 11.21μg/m³ | AQI: 47
# Step 62: Action=2 | Reward=0.508 | Energy=243.36J
# Voltage: 2.50V | Wind: 2.50m/s | PM2.5: 11.65μg/m³ | AQI: 49
# Step 63: Action=2 | Reward=0.649 | Energy=225.00J
# Voltage: 2.50V | Wind: 2.50m/s | PM2.5: 11.65μg/m³ | AQI: 49
# Step 64: Action=0 | Reward=0.649 | Energy=225.00J
# Voltage: 2.50V | Wind: 2.50m/s | PM2.5: 11.65μg/m³ | AQI: 49
# Step 65: Action=0 | Reward=0.649 | Energy=225.00J
# Voltage: 2.40V | Wind: 2.40m/s | PM2.5: 12.14μg/m³ | AQI: 51
# Step 66: Action=2 | Reward=0.695 | Energy=207.36J
# Voltage: 2.30V | Wind: 2.30m/s | PM2.5: 12.67μg/m³ | AQI: 52
# Step 67: Action=2 | Reward=0.630 | Energy=190.44J
# Voltage: 2.30V | Wind: 2.30m/s | PM2.5: 12.67μg/m³ | AQI: 52
# Step 68: Action=0 | Reward=0.630 | Energy=190.44J
# Voltage: 2.40V | Wind: 2.40m/s | PM2.5: 12.14μg/m³ | AQI: 51
# Step 69: Action=1 | Reward=0.695 | Energy=207.36J
# Voltage: 2.50V | Wind: 2.50m/s | PM2.5: 11.65μg/m³ | AQI: 49
# Step 70: Action=1 | Reward=0.649 | Energy=225.00J
# Voltage: 2.60V | Wind: 2.60m/s | PM2.5: 11.21μg/m³ | AQI: 47
# Step 71: Action=1 | Reward=0.508 | Energy=243.36J
# Voltage: 2.60V | Wind: 2.60m/s | PM2.5: 11.21μg/m³ | AQI: 47
# Step 72: Action=0 | Reward=0.508 | Energy=243.36J
# Voltage: 2.70V | Wind: 2.70m/s | PM2.5: 10.79μg/m³ | AQI: 45
# Step 73: Action=1 | Reward=0.403 | Energy=262.44J
# Voltage: 2.70V | Wind: 2.70m/s | PM2.5: 10.79μg/m³ | AQI: 45
# Step 74: Action=0 | Reward=0.403 | Energy=262.44J
# Voltage: 2.70V | Wind: 2.70m/s | PM2.5: 10.79μg/m³ | AQI: 45
# Step 75: Action=0 | Reward=0.403 | Energy=262.44J
# Voltage: 2.60V | Wind: 2.60m/s | PM2.5: 11.21μg/m³ | AQI: 47
# Step 76: Action=2 | Reward=0.508 | Energy=243.36J
# Voltage: 2.60V | Wind: 2.60m/s | PM2.5: 11.21μg/m³ | AQI: 47
# Step 77: Action=0 | Reward=0.508 | Energy=243.36J
# Voltage: 2.70V | Wind: 2.70m/s | PM2.5: 10.79μg/m³ | AQI: 45
# Step 78: Action=1 | Reward=0.403 | Energy=262.44J
# Voltage: 2.80V | Wind: 2.80m/s | PM2.5: 10.41μg/m³ | AQI: 43
# Step 79: Action=1 | Reward=0.319 | Energy=282.24J
# Voltage: 2.90V | Wind: 2.90m/s | PM2.5: 10.05μg/m³ | AQI: 42
# Step 80: Action=1 | Reward=0.249 | Energy=302.76J
# Voltage: 2.90V | Wind: 2.90m/s | PM2.5: 10.05μg/m³ | AQI: 42
# Step 81: Action=0 | Reward=0.249 | Energy=302.76J
# Voltage: 2.80V | Wind: 2.80m/s | PM2.5: 10.41μg/m³ | AQI: 43
# Step 82: Action=2 | Reward=0.319 | Energy=282.24J
# Voltage: 2.90V | Wind: 2.90m/s | PM2.5: 10.05μg/m³ | AQI: 42
# Step 83: Action=1 | Reward=0.249 | Energy=302.76J
# Voltage: 3.00V | Wind: 3.00m/s | PM2.5: 9.71μg/m³ | AQI: 40
# Step 84: Action=1 | Reward=0.188 | Energy=324.00J
# Voltage: 2.90V | Wind: 2.90m/s | PM2.5: 10.05μg/m³ | AQI: 42
# Step 85: Action=2 | Reward=0.249 | Energy=302.76J
# Voltage: 3.00V | Wind: 3.00m/s | PM2.5: 9.71μg/m³ | AQI: 40
# Step 86: Action=1 | Reward=0.188 | Energy=324.00J
# Voltage: 3.00V | Wind: 3.00m/s | PM2.5: 9.71μg/m³ | AQI: 40
# Step 87: Action=0 | Reward=0.188 | Energy=324.00J
# Voltage: 3.10V | Wind: 3.10m/s | PM2.5: 9.40μg/m³ | AQI: 39
# Step 88: Action=1 | Reward=0.134 | Energy=345.96J
# Voltage: 3.00V | Wind: 3.00m/s | PM2.5: 9.71μg/m³ | AQI: 40
# Step 89: Action=2 | Reward=0.188 | Energy=324.00J
# Voltage: 2.90V | Wind: 2.90m/s | PM2.5: 10.05μg/m³ | AQI: 42
# Step 90: Action=2 | Reward=0.249 | Energy=302.76J
# Voltage: 3.00V | Wind: 3.00m/s | PM2.5: 9.71μg/m³ | AQI: 40
# Step 91: Action=1 | Reward=0.188 | Energy=324.00J
# Voltage: 3.00V | Wind: 3.00m/s | PM2.5: 9.71μg/m³ | AQI: 40
# Step 92: Action=0 | Reward=0.188 | Energy=324.00J
# Voltage: 3.00V | Wind: 3.00m/s | PM2.5: 9.71μg/m³ | AQI: 40
# Step 93: Action=0 | Reward=0.188 | Energy=324.00J
# Voltage: 3.10V | Wind: 3.10m/s | PM2.5: 9.40μg/m³ | AQI: 39
# Step 94: Action=1 | Reward=0.134 | Energy=345.96J
# Voltage: 3.10V | Wind: 3.10m/s | PM2.5: 9.40μg/m³ | AQI: 39
# Step 95: Action=0 | Reward=0.134 | Energy=345.96J
# Voltage: 3.20V | Wind: 3.20m/s | PM2.5: 9.11μg/m³ | AQI: 38
# Step 96: Action=1 | Reward=0.085 | Energy=368.64J
# Voltage: 3.30V | Wind: 3.30m/s | PM2.5: 8.83μg/m³ | AQI: 37
# Step 97: Action=1 | Reward=0.039 | Energy=392.04J
# Voltage: 3.20V | Wind: 3.20m/s | PM2.5: 9.11μg/m³ | AQI: 38
# Step 98: Action=2 | Reward=0.085 | Energy=368.64J
# Voltage: 3.30V | Wind: 3.30m/s | PM2.5: 8.83μg/m³ | AQI: 37
# Step 99: Action=1 | Reward=0.039 | Energy=392.04J
# Voltage: 3.30V | Wind: 3.30m/s | PM2.5: 8.83μg/m³ | AQI: 37
# Step 100: Action=0 | Reward=0.039 | Energy=392.04J

# %%
class TrainAndLoggingCallback(BaseCallback):

    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path

    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'best_model_{}'.format(self.n_calls))
            self.model.save(model_path)

        return True
    
CHECKPOINT_DIR = './ppo/train/'
LOG_DIR = './ppo/logs/'
callback = TrainAndLoggingCallback(check_freq=1000, save_path=CHECKPOINT_DIR)

# %%
env = AirQualityDiscreteEnv()
# check_env(env)  # Validate environment

model = PPO("MlpPolicy", env, verbose=1,
            learning_rate=3e-4,
            n_steps=2048,
            batch_size=64,
            gamma=0.99,
            gae_lambda=0.95,
            clip_range=0.2)

model.learn(total_timesteps=100000)
model.save("aqi_fan_controller")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 160      |
# |    ep_rew_mean     | 64.4     |
# | time/              |          |
# |    fps             | 7918     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 69.3        |
# | time/                   |             |
# |    fps                  | 5204        |
# |    iterations           | 2           |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008909017 |
# |    clip_fraction        | 0.0806      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.0696      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.71        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00659    |
# |    value_loss           | 12.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 71.4        |
# | time/                   |             |
# |    fps                  | 4770        |
# |    iterations           | 3           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010507848 |
# |    clip_fraction        | 0.0858      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.406       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.02        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00958    |
# |    value_loss           | 9.59        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 73.1        |
# | time/                   |             |
# |    fps                  | 4661        |
# |    iterations           | 4           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.011166012 |
# |    clip_fraction        | 0.0792      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.625       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.29        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0125     |
# |    value_loss           | 11.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 74.2        |
# | time/                   |             |
# |    fps                  | 4592        |
# |    iterations           | 5           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.010101918 |
# |    clip_fraction        | 0.062       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.568       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.83        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00249    |
# |    value_loss           | 10.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 75.1        |
# | time/                   |             |
# |    fps                  | 4539        |
# |    iterations           | 6           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.010027665 |
# |    clip_fraction        | 0.083       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.801       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.15        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00885    |
# |    value_loss           | 8.53        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 76.5        |
# | time/                   |             |
# |    fps                  | 4522        |
# |    iterations           | 7           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.015647264 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.901       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.92        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00881    |
# |    value_loss           | 4.77        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 78.6        |
# | time/                   |             |
# |    fps                  | 4507        |
# |    iterations           | 8           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.015065275 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.956       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.342       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00819    |
# |    value_loss           | 2.6         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 160          |
# |    ep_rew_mean          | 81.5         |
# | time/                   |              |
# |    fps                  | 4494         |
# |    iterations           | 9            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0062524066 |
# |    clip_fraction        | 0.0559       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.993       |
# |    explained_variance   | 0.973        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.68         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00411     |
# |    value_loss           | 2.66         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 83.8        |
# | time/                   |             |
# |    fps                  | 4486        |
# |    iterations           | 10          |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.004734281 |
# |    clip_fraction        | 0.0729      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.993      |
# |    explained_variance   | 0.979       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.814       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00442    |
# |    value_loss           | 2.18        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 85.1        |
# | time/                   |             |
# |    fps                  | 4457        |
# |    iterations           | 11          |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.007599419 |
# |    clip_fraction        | 0.0698      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.961      |
# |    explained_variance   | 0.983       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.528       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00721    |
# |    value_loss           | 1.89        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 87.3        |
# | time/                   |             |
# |    fps                  | 4430        |
# |    iterations           | 12          |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.009803961 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.935      |
# |    explained_variance   | 0.989       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.435       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00901    |
# |    value_loss           | 1.36        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 89.3        |
# | time/                   |             |
# |    fps                  | 4416        |
# |    iterations           | 13          |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.009439794 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.864      |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.31        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0077     |
# |    value_loss           | 1.02        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 90.7        |
# | time/                   |             |
# |    fps                  | 4400        |
# |    iterations           | 14          |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.008011395 |
# |    clip_fraction        | 0.0736      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.833      |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.293       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00345    |
# |    value_loss           | 1.01        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 160        |
# |    ep_rew_mean          | 92.2       |
# | time/                   |            |
# |    fps                  | 4385       |
# |    iterations           | 15         |
# |    time_elapsed         | 7          |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.01081239 |
# |    clip_fraction        | 0.17       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.833     |
# |    explained_variance   | 0.99       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.58       |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.0163    |
# |    value_loss           | 1.44       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 93.4        |
# | time/                   |             |
# |    fps                  | 4358        |
# |    iterations           | 16          |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.009676453 |
# |    clip_fraction        | 0.0842      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.824      |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.212       |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00382    |
# |    value_loss           | 0.552       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 160        |
# |    ep_rew_mean          | 94.5       |
# | time/                   |            |
# |    fps                  | 4354       |
# |    iterations           | 17         |
# |    time_elapsed         | 7          |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.01150669 |
# |    clip_fraction        | 0.0993     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.741     |
# |    explained_variance   | 0.996      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.213      |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.0102    |
# |    value_loss           | 0.614      |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 160          |
# |    ep_rew_mean          | 95.6         |
# | time/                   |              |
# |    fps                  | 4351         |
# |    iterations           | 18           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0065135923 |
# |    clip_fraction        | 0.0873       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.714       |
# |    explained_variance   | 0.997        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.182        |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00425     |
# |    value_loss           | 0.548        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 160          |
# |    ep_rew_mean          | 96.9         |
# | time/                   |              |
# |    fps                  | 4348         |
# |    iterations           | 19           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0063651106 |
# |    clip_fraction        | 0.0897       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.714       |
# |    explained_variance   | 0.996        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.35         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00344     |
# |    value_loss           | 0.661        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 97.6        |
# | time/                   |             |
# |    fps                  | 4334        |
# |    iterations           | 20          |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.003496448 |
# |    clip_fraction        | 0.0673      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.702      |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.331       |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00338    |
# |    value_loss           | 0.599       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 160          |
# |    ep_rew_mean          | 98.7         |
# | time/                   |              |
# |    fps                  | 4328         |
# |    iterations           | 21           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0046913577 |
# |    clip_fraction        | 0.0792       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.714       |
# |    explained_variance   | 0.998        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.149        |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00246     |
# |    value_loss           | 0.391        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 100         |
# | time/                   |             |
# |    fps                  | 4322        |
# |    iterations           | 22          |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.009552194 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.678      |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.166       |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00457    |
# |    value_loss           | 0.344       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 101         |
# | time/                   |             |
# |    fps                  | 4319        |
# |    iterations           | 23          |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.015981428 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.72       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.15        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0137     |
# |    value_loss           | 0.333       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 102         |
# | time/                   |             |
# |    fps                  | 4313        |
# |    iterations           | 24          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.010198103 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.713      |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0629      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00164    |
# |    value_loss           | 0.203       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 102         |
# | time/                   |             |
# |    fps                  | 4316        |
# |    iterations           | 25          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.010010157 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.698      |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0696      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | 0.000333    |
# |    value_loss           | 0.174       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 103         |
# | time/                   |             |
# |    fps                  | 4319        |
# |    iterations           | 26          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.019794509 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.685      |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0153      |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00732    |
# |    value_loss           | 0.162       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 160        |
# |    ep_rew_mean          | 104        |
# | time/                   |            |
# |    fps                  | 4322       |
# |    iterations           | 27         |
# |    time_elapsed         | 12         |
# |    total_timesteps      | 55296      |
# | train/                  |            |
# |    approx_kl            | 0.08190873 |
# |    clip_fraction        | 0.152      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.645     |
# |    explained_variance   | 0.999      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.044      |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.0167    |
# |    value_loss           | 0.166      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 104         |
# | time/                   |             |
# |    fps                  | 4319        |
# |    iterations           | 28          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.027065216 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.643      |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.05        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0104     |
# |    value_loss           | 0.154       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 105         |
# | time/                   |             |
# |    fps                  | 4320        |
# |    iterations           | 29          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.015543303 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.649      |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0182      |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00203    |
# |    value_loss           | 0.0949      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 105         |
# | time/                   |             |
# |    fps                  | 4321        |
# |    iterations           | 30          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.013173714 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.638      |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0152      |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00396    |
# |    value_loss           | 0.0938      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 106         |
# | time/                   |             |
# |    fps                  | 4322        |
# |    iterations           | 31          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.013447341 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.592      |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0199      |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00196    |
# |    value_loss           | 0.0951      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 160        |
# |    ep_rew_mean          | 106        |
# | time/                   |            |
# |    fps                  | 4315       |
# |    iterations           | 32         |
# |    time_elapsed         | 15         |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.02097604 |
# |    clip_fraction        | 0.178      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.624     |
# |    explained_variance   | 1          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0351     |
# |    n_updates            | 310        |
# |    policy_gradient_loss | -0.00336   |
# |    value_loss           | 0.0763     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 106         |
# | time/                   |             |
# |    fps                  | 4316        |
# |    iterations           | 33          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.015605367 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.568      |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00654     |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00344    |
# |    value_loss           | 0.0829      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 107         |
# | time/                   |             |
# |    fps                  | 4315        |
# |    iterations           | 34          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.013582695 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.512      |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.041       |
# |    n_updates            | 330         |
# |    policy_gradient_loss | 0.00378     |
# |    value_loss           | 0.0848      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 160        |
# |    ep_rew_mean          | 107        |
# | time/                   |            |
# |    fps                  | 4310       |
# |    iterations           | 35         |
# |    time_elapsed         | 16         |
# |    total_timesteps      | 71680      |
# | train/                  |            |
# |    approx_kl            | 0.02459802 |
# |    clip_fraction        | 0.133      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.473     |
# |    explained_variance   | 1          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0555     |
# |    n_updates            | 340        |
# |    policy_gradient_loss | 0.0007     |
# |    value_loss           | 0.105      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 107         |
# | time/                   |             |
# |    fps                  | 4306        |
# |    iterations           | 36          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.013222592 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.488      |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0186      |
# |    n_updates            | 350         |
# |    policy_gradient_loss | 0.00213     |
# |    value_loss           | 0.0574      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 108         |
# | time/                   |             |
# |    fps                  | 4303        |
# |    iterations           | 37          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.008855326 |
# |    clip_fraction        | 0.0972      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.445      |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -4.85e-05   |
# |    n_updates            | 360         |
# |    policy_gradient_loss | 0.00445     |
# |    value_loss           | 0.0511      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 108         |
# | time/                   |             |
# |    fps                  | 4303        |
# |    iterations           | 38          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.008218215 |
# |    clip_fraction        | 0.1         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.396      |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0226      |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00315    |
# |    value_loss           | 0.075       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 108         |
# | time/                   |             |
# |    fps                  | 4279        |
# |    iterations           | 39          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.022973673 |
# |    clip_fraction        | 0.0657      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.389      |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0272      |
# |    n_updates            | 380         |
# |    policy_gradient_loss | 6.52e-05    |
# |    value_loss           | 0.062       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 108         |
# | time/                   |             |
# |    fps                  | 4261        |
# |    iterations           | 40          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.036900397 |
# |    clip_fraction        | 0.181       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.428      |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00195    |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0201     |
# |    value_loss           | 0.0536      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 108         |
# | time/                   |             |
# |    fps                  | 4252        |
# |    iterations           | 41          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.028297644 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.356      |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0511      |
# |    n_updates            | 400         |
# |    policy_gradient_loss | 0.00386     |
# |    value_loss           | 0.0846      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 108         |
# | time/                   |             |
# |    fps                  | 4251        |
# |    iterations           | 42          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.015529012 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.347      |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0309      |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.000204   |
# |    value_loss           | 0.071       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 160        |
# |    ep_rew_mean          | 109        |
# | time/                   |            |
# |    fps                  | 4239       |
# |    iterations           | 43         |
# |    time_elapsed         | 20         |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.03369394 |
# |    clip_fraction        | 0.114      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.341     |
# |    explained_variance   | 1          |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00197   |
# |    n_updates            | 420        |
# |    policy_gradient_loss | -0.000857  |
# |    value_loss           | 0.0636     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 160        |
# |    ep_rew_mean          | 109        |
# | time/                   |            |
# |    fps                  | 4227       |
# |    iterations           | 44         |
# |    time_elapsed         | 21         |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.01520993 |
# |    clip_fraction        | 0.115      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.352     |
# |    explained_variance   | 1          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0291     |
# |    n_updates            | 430        |
# |    policy_gradient_loss | 0.00775    |
# |    value_loss           | 0.0452     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 109         |
# | time/                   |             |
# |    fps                  | 4227        |
# |    iterations           | 45          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.013491174 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.313      |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0044      |
# |    n_updates            | 440         |
# |    policy_gradient_loss | 0.0167      |
# |    value_loss           | 0.0399      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 109         |
# | time/                   |             |
# |    fps                  | 4227        |
# |    iterations           | 46          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.025527108 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.305      |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0288      |
# |    n_updates            | 450         |
# |    policy_gradient_loss | 0.00839     |
# |    value_loss           | 0.0668      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 109         |
# | time/                   |             |
# |    fps                  | 4229        |
# |    iterations           | 47          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.020693958 |
# |    clip_fraction        | 0.0965      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.267      |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0412      |
# |    n_updates            | 460         |
# |    policy_gradient_loss | 0.00651     |
# |    value_loss           | 0.0382      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 109         |
# | time/                   |             |
# |    fps                  | 4231        |
# |    iterations           | 48          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.009877194 |
# |    clip_fraction        | 0.0691      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.2        |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00675     |
# |    n_updates            | 470         |
# |    policy_gradient_loss | 0.00645     |
# |    value_loss           | 0.0452      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 109         |
# | time/                   |             |
# |    fps                  | 4233        |
# |    iterations           | 49          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.021892207 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.282      |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00131    |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00343    |
# |    value_loss           | 0.0381      |
# -----------------------------------------

# %%
from stable_baselines3 import PPO
import os

# %%
# Create and wrap the environment
# Initialize DQN model with more reasonable parameters
env = AirQualityDiscreteEnv()
model = PPO(
    'MlpPolicy', 
    env, 
    tensorboard_log=LOG_DIR, 
    verbose=1,
    n_steps=2048,        # Number of steps to run for each environment per update
    batch_size=64,       # Minibatch size
    n_epochs=10,         # Number of epoch when optimizing the surrogate loss
    gamma=0.99,          # Discount factor
    gae_lambda=0.95,     # Factor for trade-off of bias vs variance for GAE
    ent_coef=0.01,       # Entropy coefficient
    learning_rate=3e-4,  # Learning rate
    clip_range=0.2,      # Clipping parameter
)
# Set up and attach custom logger
new_logger = configure(LOG_DIR, ["stdout", "csv", "tensorboard"])
model.set_logger(new_logger)

# Train the model
model.learn(total_timesteps=100000, callback=callback)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to ./ppo/logs/
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 160      |
# |    ep_rew_mean     | 39.9     |
# | time/              |          |
# |    fps             | 8082     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 51          |
# | time/                   |             |
# |    fps                  | 5319        |
# |    iterations           | 2           |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.010949289 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.0181      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.36        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.014      |
# |    value_loss           | 16          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 59.8        |
# | time/                   |             |
# |    fps                  | 4858        |
# |    iterations           | 3           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010133486 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.111      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.77        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00706    |
# |    value_loss           | 9.84        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 65.2        |
# | time/                   |             |
# |    fps                  | 4730        |
# |    iterations           | 4           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009176197 |
# |    clip_fraction        | 0.0825      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.416       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.76        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0101     |
# |    value_loss           | 12.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 68.8        |
# | time/                   |             |
# |    fps                  | 4619        |
# |    iterations           | 5           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.005528287 |
# |    clip_fraction        | 0.0251      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.571       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.24        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00476    |
# |    value_loss           | 12          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 71.5        |
# | time/                   |             |
# |    fps                  | 4585        |
# |    iterations           | 6           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.010421628 |
# |    clip_fraction        | 0.0812      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.683       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.79        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00614    |
# |    value_loss           | 11.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 160          |
# |    ep_rew_mean          | 73.2         |
# | time/                   |              |
# |    fps                  | 4566         |
# |    iterations           | 7            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0075437673 |
# |    clip_fraction        | 0.073        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0.809        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.87         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00398     |
# |    value_loss           | 9.42         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 74          |
# | time/                   |             |
# |    fps                  | 4556        |
# |    iterations           | 8           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.006384164 |
# |    clip_fraction        | 0.0258      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.897       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.754       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00143    |
# |    value_loss           | 5.48        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 79.7        |
# | time/                   |             |
# |    fps                  | 4544        |
# |    iterations           | 9           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.016066106 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.957       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.731       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00886    |
# |    value_loss           | 2.36        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 82.8        |
# | time/                   |             |
# |    fps                  | 4529        |
# |    iterations           | 10          |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.008294236 |
# |    clip_fraction        | 0.0576      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.978       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.448       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00676    |
# |    value_loss           | 2.09        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 84          |
# | time/                   |             |
# |    fps                  | 4521        |
# |    iterations           | 11          |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.023107093 |
# |    clip_fraction        | 0.324       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.418       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0187     |
# |    value_loss           | 1.29        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 85.5        |
# | time/                   |             |
# |    fps                  | 4512        |
# |    iterations           | 12          |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.008936484 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.465       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00883    |
# |    value_loss           | 1.44        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 86.5        |
# | time/                   |             |
# |    fps                  | 4505        |
# |    iterations           | 13          |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.013121579 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.295       |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00459    |
# |    value_loss           | 1.01        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 87.5        |
# | time/                   |             |
# |    fps                  | 4494        |
# |    iterations           | 14          |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.010180637 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.991       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.475       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0166     |
# |    value_loss           | 1.27        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 89          |
# | time/                   |             |
# |    fps                  | 4484        |
# |    iterations           | 15          |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.015507893 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.31        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0123     |
# |    value_loss           | 0.717       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 91          |
# | time/                   |             |
# |    fps                  | 4477        |
# |    iterations           | 16          |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.010780231 |
# |    clip_fraction        | 0.222       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.997      |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.273       |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0157     |
# |    value_loss           | 0.679       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 92.7        |
# | time/                   |             |
# |    fps                  | 4473        |
# |    iterations           | 17          |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.014509479 |
# |    clip_fraction        | 0.23        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.983      |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.152       |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0133     |
# |    value_loss           | 0.371       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 94.6        |
# | time/                   |             |
# |    fps                  | 4471        |
# |    iterations           | 18          |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.009561379 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.962      |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0641      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0113     |
# |    value_loss           | 0.354       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 96.5        |
# | time/                   |             |
# |    fps                  | 4472        |
# |    iterations           | 19          |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.009020869 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.95       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0884      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00722    |
# |    value_loss           | 0.298       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 97.9        |
# | time/                   |             |
# |    fps                  | 4455        |
# |    iterations           | 20          |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.010791486 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.932      |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0397      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0051     |
# |    value_loss           | 0.236       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 99.4        |
# | time/                   |             |
# |    fps                  | 4451        |
# |    iterations           | 21          |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.010063273 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.922      |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0316      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00332    |
# |    value_loss           | 0.161       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 160        |
# |    ep_rew_mean          | 101        |
# | time/                   |            |
# |    fps                  | 4447       |
# |    iterations           | 22         |
# |    time_elapsed         | 10         |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.01260306 |
# |    clip_fraction        | 0.201      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.89      |
# |    explained_variance   | 0.999      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0542     |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.00409   |
# |    value_loss           | 0.141      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 102         |
# | time/                   |             |
# |    fps                  | 4446        |
# |    iterations           | 23          |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.009296551 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.899      |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0149      |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00481    |
# |    value_loss           | 0.1         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 160        |
# |    ep_rew_mean          | 103        |
# | time/                   |            |
# |    fps                  | 4445       |
# |    iterations           | 24         |
# |    time_elapsed         | 11         |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.01013662 |
# |    clip_fraction        | 0.139      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.882     |
# |    explained_variance   | 0.999      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0287     |
# |    n_updates            | 230        |
# |    policy_gradient_loss | 0.00122    |
# |    value_loss           | 0.111      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 104         |
# | time/                   |             |
# |    fps                  | 4439        |
# |    iterations           | 25          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.010616982 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.872      |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0439      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.000167   |
# |    value_loss           | 0.0842      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 104         |
# | time/                   |             |
# |    fps                  | 4432        |
# |    iterations           | 26          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.014380325 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.854      |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0311      |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00399    |
# |    value_loss           | 0.0954      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 105         |
# | time/                   |             |
# |    fps                  | 4414        |
# |    iterations           | 27          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.013376305 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.832      |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0563      |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.000702   |
# |    value_loss           | 0.0816      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 105         |
# | time/                   |             |
# |    fps                  | 4401        |
# |    iterations           | 28          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.014167188 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.804      |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00829     |
# |    n_updates            | 270         |
# |    policy_gradient_loss | 0.00146     |
# |    value_loss           | 0.0661      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 105         |
# | time/                   |             |
# |    fps                  | 4396        |
# |    iterations           | 29          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.015360055 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.769      |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0102      |
# |    n_updates            | 280         |
# |    policy_gradient_loss | 0.00102     |
# |    value_loss           | 0.0615      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 106         |
# | time/                   |             |
# |    fps                  | 4393        |
# |    iterations           | 30          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.017052114 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.756      |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00735    |
# |    n_updates            | 290         |
# |    policy_gradient_loss | 0.00381     |
# |    value_loss           | 0.0575      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 106         |
# | time/                   |             |
# |    fps                  | 4392        |
# |    iterations           | 31          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.009220256 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.749      |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0422      |
# |    n_updates            | 300         |
# |    policy_gradient_loss | 0.00178     |
# |    value_loss           | 0.058       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 106         |
# | time/                   |             |
# |    fps                  | 4388        |
# |    iterations           | 32          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.014677286 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.714      |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0011     |
# |    n_updates            | 310         |
# |    policy_gradient_loss | 0.00124     |
# |    value_loss           | 0.0577      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 107         |
# | time/                   |             |
# |    fps                  | 4389        |
# |    iterations           | 33          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.016667996 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.68       |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.05        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | 0.00381     |
# |    value_loss           | 0.0545      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 107         |
# | time/                   |             |
# |    fps                  | 4388        |
# |    iterations           | 34          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.015279396 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.659      |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0197      |
# |    n_updates            | 330         |
# |    policy_gradient_loss | 0.00671     |
# |    value_loss           | 0.0489      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 107         |
# | time/                   |             |
# |    fps                  | 4389        |
# |    iterations           | 35          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.017389497 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.666      |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0304      |
# |    n_updates            | 340         |
# |    policy_gradient_loss | 0.00521     |
# |    value_loss           | 0.0452      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 160        |
# |    ep_rew_mean          | 107        |
# | time/                   |            |
# |    fps                  | 4390       |
# |    iterations           | 36         |
# |    time_elapsed         | 16         |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.05629804 |
# |    clip_fraction        | 0.222      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.628     |
# |    explained_variance   | 1          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.017      |
# |    n_updates            | 350        |
# |    policy_gradient_loss | 0.017      |
# |    value_loss           | 0.0449     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 107         |
# | time/                   |             |
# |    fps                  | 4390        |
# |    iterations           | 37          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.020084705 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.583      |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00117     |
# |    n_updates            | 360         |
# |    policy_gradient_loss | 0.0106      |
# |    value_loss           | 0.038       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 108         |
# | time/                   |             |
# |    fps                  | 4390        |
# |    iterations           | 38          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.012834664 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.545      |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00427     |
# |    n_updates            | 370         |
# |    policy_gradient_loss | 0.00652     |
# |    value_loss           | 0.0352      |
# -----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 160      |
# |    ep_rew_mean          | 108      |
# | time/                   |          |
# |    fps                  | 4390     |
# |    iterations           | 39       |
# |    time_elapsed         | 18       |
# |    total_timesteps      | 79872    |
# | train/                  |          |
# |    approx_kl            | 0.011856 |
# |    clip_fraction        | 0.142    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.536   |
# |    explained_variance   | 1        |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.00455 |
# |    n_updates            | 380      |
# |    policy_gradient_loss | 0.00881  |
# |    value_loss           | 0.0348   |
# --------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 160        |
# |    ep_rew_mean          | 108        |
# | time/                   |            |
# |    fps                  | 4390       |
# |    iterations           | 40         |
# |    time_elapsed         | 18         |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.02364765 |
# |    clip_fraction        | 0.165      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.539     |
# |    explained_variance   | 1          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0149     |
# |    n_updates            | 390        |
# |    policy_gradient_loss | 0.00746    |
# |    value_loss           | 0.0322     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 108         |
# | time/                   |             |
# |    fps                  | 4376        |
# |    iterations           | 41          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.014467883 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.555      |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0164      |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00331    |
# |    value_loss           | 0.0377      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 108         |
# | time/                   |             |
# |    fps                  | 4373        |
# |    iterations           | 42          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.021391539 |
# |    clip_fraction        | 0.204       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.534      |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0133     |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00311    |
# |    value_loss           | 0.0297      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 108         |
# | time/                   |             |
# |    fps                  | 4372        |
# |    iterations           | 43          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.012571653 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.52       |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0376      |
# |    n_updates            | 420         |
# |    policy_gradient_loss | 0.0108      |
# |    value_loss           | 0.0308      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 108         |
# | time/                   |             |
# |    fps                  | 4374        |
# |    iterations           | 44          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.013428334 |
# |    clip_fraction        | 0.181       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.515      |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0182      |
# |    n_updates            | 430         |
# |    policy_gradient_loss | 0.00694     |
# |    value_loss           | 0.0327      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 160        |
# |    ep_rew_mean          | 108        |
# | time/                   |            |
# |    fps                  | 4374       |
# |    iterations           | 45         |
# |    time_elapsed         | 21         |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.01158479 |
# |    clip_fraction        | 0.167      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.506     |
# |    explained_variance   | 1          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0254     |
# |    n_updates            | 440        |
# |    policy_gradient_loss | 0.00855    |
# |    value_loss           | 0.0309     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 108         |
# | time/                   |             |
# |    fps                  | 4373        |
# |    iterations           | 46          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.042116404 |
# |    clip_fraction        | 0.242       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.467      |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00309     |
# |    n_updates            | 450         |
# |    policy_gradient_loss | 0.0143      |
# |    value_loss           | 0.0272      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 108         |
# | time/                   |             |
# |    fps                  | 4374        |
# |    iterations           | 47          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.018618492 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.448      |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000468    |
# |    n_updates            | 460         |
# |    policy_gradient_loss | 0.00868     |
# |    value_loss           | 0.0338      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 108         |
# | time/                   |             |
# |    fps                  | 4377        |
# |    iterations           | 48          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.018534578 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.45       |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0586      |
# |    n_updates            | 470         |
# |    policy_gradient_loss | 0.00627     |
# |    value_loss           | 0.0479      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 109         |
# | time/                   |             |
# |    fps                  | 4378        |
# |    iterations           | 49          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.031868175 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.462      |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.016       |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00673    |
# |    value_loss           | 0.0657      |
# -----------------------------------------

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load training logs
logs = pd.read_csv('./ppo/logs/progress.csv')

# %%
# Plot: Mean Episode Reward vs. Timesteps
plt.figure(figsize=(12, 6))
plt.plot(logs['time/total_timesteps'], logs['rollout/ep_rew_mean'], label='Mean Episode Reward', color='royalblue')
plt.xlabel('Total Timesteps')
plt.ylabel('Episode Reward (Mean)')
plt.title('PPO Mean Episode Reward (First 40k Steps)')
plt.grid(True)
plt.legend()
plt.show()

# Plot: Episode Length vs. Timesteps
plt.figure(figsize=(12, 6))
plt.plot(logs['time/total_timesteps'], logs['rollout/ep_len_mean'], label='Mean Episode Length', color='seagreen')
plt.xlabel('Total Timesteps')
plt.ylabel('Episode Length (Mean)')
plt.title('PPO Mean Episode Length (First 40k Steps)')
plt.grid(True)
plt.legend()
plt.show()
